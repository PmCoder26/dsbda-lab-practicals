# %%
# importing dependencies.
import numpy as np
import pandas as pd

# %%
# part-1 of this assignment.
# loading the required dataset.
df = pd.read_csv('../data/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# describing the statistical description.
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# getting information about the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# checking the null values.
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# now grouping by species.
grouped = df.groupby('Species')
grouped.size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# describing the statistics of each species.
for group, data in grouped:
    print('-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-')
    print(f'Species: {group}')    
    print(data.describe())
# Out:
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Species: Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-
# Species: Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# ...

# %%
# now part-2 of this assignment.

# %%
# loading the required dataset.
df2 = pd.read_csv('../data/loan.csv')
df2
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 495         495  LP002586  Female     Yes          1      Graduate
# 496         496  LP002587    Male     Yes          0  Not Graduate
# 497         497  LP002588    Male     Yes          0      Graduate
# 498         498  LP002600    Male     Yes          1      Graduate
# 499         499  LP002602    Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5849                0.0         NaN
# ...

# %%
# getting the statistical description.
df2.describe()
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  500.000000       500.000000         500.000000  482.000000
# mean   249.500000      5493.644000        1506.307840  144.020747
# std    144.481833      6515.668972        2134.432188   82.344919
# min      0.000000       150.000000           0.000000   17.000000
# 25%    124.750000      2874.500000           0.000000  100.000000
# 50%    249.500000      3854.000000        1125.500000  126.500000
# 75%    374.250000      5764.000000        2253.250000  161.500000
# max    499.000000     81000.000000       20000.000000  700.000000
#
#        Loan_Amount_Term  Credit_History
# count        486.000000      459.000000
# mean         342.543210        0.843137
# std           63.834977        0.364068
# min           12.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %%
# getting the information about the dataset.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         500 non-null    int64
#  1   Loan_ID            500 non-null    object
#  2   Gender             491 non-null    object
#  3   Married            497 non-null    object
#  4   Dependents         488 non-null    object
#  5   Education          500 non-null    object
#  6   Self_Employed      473 non-null    object
#  7   ApplicantIncome    500 non-null    int64
#  8   CoapplicantIncome  500 non-null    float64
#  9   LoanAmount         482 non-null    float64
#  10  Loan_Amount_Term   486 non-null    float64
#  11  Credit_History     459 non-null    float64
#  12  Property_Area      500 non-null    object
#  13  Loan_Status        500 non-null    object
#  14  Total_Income       500 non-null    object
# dtypes: float64(4), int64(2), object(9)
# ...

# %%
# now determining the columnwise null values count.
df2.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                9
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       41
# Property_Area         0
# Loan_Status           0
# Total_Income          0
# dtype: int64

# %%
# dealing with the null values and converting the datatypes.
df2.dropna(axis=0, how='any', inplace=True)
df2['Total_Income'] = df2['Total_Income'].str[1:]
df2['Total_Income'] = df2['Total_Income'].str.replace(',', '')
df2['Total_Income'] = df2['Total_Income'].astype('float')
print('The dataframe after removing the null field rows is')
df2
# Out:
# The dataframe after removing the null field rows is
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# 5             5  LP001011    Male     Yes          2      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 494         494  LP002585    Male     Yes          0      Graduate
# 495         495  LP002586  Female     Yes          1      Graduate
# 496         496  LP002587    Male     Yes          0  Not Graduate
# 498         498  LP002600    Male     Yes          1      Graduate
# 499         499  LP002602    Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %%
# now re-checking the df2 if null values exists.
df2.isnull().sum()
# Out:
# Unnamed: 0           0
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Total_Income         0
# dtype: int64

# %%
# now grouping the data for gender and displaying the statistical description.
grouped = df2.groupby('Gender')
for group, data in grouped:
    print('-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
    print(f'For {group}')
    print(f'Statistical Description:')
    print(data.describe())
# Out:
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# For Female
# Statistical Description:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count    69.00000        69.000000          69.000000   69.000000
# mean    257.84058      4696.159420         729.492754  122.565217
# std     135.60015      3254.415537        1457.161045   55.994085
# min      17.00000      1378.000000           0.000000   30.000000
# 25%     136.00000      2645.000000           0.000000   81.000000
# 50%     283.00000      3812.000000           0.000000  115.000000
# 75%     370.00000      4666.000000        1560.000000  144.000000
# max     495.00000     17263.000000        8980.000000  286.000000
#
#        Loan_Amount_Term  Credit_History  Total_Income
# count         69.000000       69.000000     69.000000
# mean         352.173913        0.840580   5425.652174
# std           53.540242        0.368749   3182.780572
# min           36.000000        0.000000   1963.000000
# ...

# %%
# statistical description for numerical variables grouped by the categorical variables.
categorical_columns = df2.select_dtypes(include=['object']).drop(columns=['Loan_ID']).columns
numerical_columns = df2.select_dtypes(include=['number']).columns
summary_stats = df2.groupby(categorical_columns.tolist())[numerical_columns].describe()
summary_stats.head(20)
# Out:
#                                                                                Unnamed: 0  \
#                                                                                     count
# Gender Married Dependents Education    Self_Employed Property_Area Loan_Status
# Female No      0          Graduate     No            Rural         N                  3.0
#                                                                    Y                  4.0
#                                                      Semiurban     N                  5.0
#                                                                    Y                 10.0
#                                                      Urban         N                  3.0
#                                                                    Y                  7.0
#                                        Yes           Rural         N                  1.0
# ...
