# %%
import pandas as pd
import numpy as np

# %%
missiing_values_format = ['NA', 'null', '--', 'NaN', 'N/A', 'n/a', 'NaN', 'nan', '?', 'N.A', 'na']
df = pd.read_csv('data/academic_data.csv', na_values=missiing_values_format)
df
# Out:
#    Firstname Lastname Gender   SPOS  DSBDA     WT     DA
# 0         LA      Roy      M   85.0   88.0   90.0   92.0
# 1         SA    Dixit      F   90.0   90.0   94.0   95.0
# 2         AB   Danial      M    NaN    NaN  100.0   80.0
# 3         DA   Kapoor      M   95.0   86.0  500.0   82.0
# 4         SA      Jha      F    NaN   84.0   98.0   84.0
# 5         WS   Thakur      F   87.0    NaN   97.0   86.0
# 6         DY   Kapoor      M   81.0   80.0   96.0   89.0
# 7         JK   Khanna      F   40.0   88.0   95.0   87.0
# 8         RT  Pardesi      M   10.0   96.0   94.0   88.0
# 9         UV  Pardesi      M    9.0    NaN   93.0   96.0
# 10        MN    Desai      F  200.0   87.0    NaN    NaN
# 11        BC    Patel      F  300.0    NaN   88.0  300.0
# 12        DS    Patel      F  300.0    NaN   88.0  100.0
# 13        XY    Patel      F  300.0    NaN   88.0  200.0
# 14        BC    Patel      F  300.0    NaN   88.0  300.0

# %%
df.describe()
# Out:
#              SPOS          WT          DA
# count   13.000000   14.000000   14.000000
# mean   145.923077  122.071429  127.071429
# std    116.706513  108.850967   79.156577
# min      9.000000   88.000000   80.000000
# 25%     81.000000   88.500000   86.250000
# 50%     90.000000   94.000000   90.500000
# 75%    300.000000   96.750000   99.000000
# max    300.000000  500.000000  300.000000

# %%
df.head(10)
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT    DA
# 0        LA      Roy      M  85.0    88   90.0  92.0
# 1        SA    Dixit      F  90.0    90   94.0  95.0
# 2        AB   Danial      M   NaN    na  100.0  80.0
# 3        DA   Kapoor      M  95.0    86  500.0  82.0
# 4        SA      Jha      F   NaN    84   98.0  84.0
# 5        WS   Thakur      F  87.0   NaN   97.0  86.0
# 6        DY   Kapoor      M  81.0    80   96.0  89.0
# 7        JK   Khanna      F  40.0    88   95.0  87.0
# 8        RT  Pardesi      M  10.0    96   94.0  88.0
# 9        UV  Pardesi      M   9.0   NaN   93.0  96.0

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT     DA
# 0         LA      Roy      M   85.0    88   90.0   92.0
# 1         SA    Dixit      F   90.0    90   94.0   95.0
# 2         AB   Danial      M    NaN    na  100.0   80.0
# 3         DA   Kapoor      M   95.0    86  500.0   82.0
# 4         SA      Jha      F    NaN    84   98.0   84.0
# 5         WS   Thakur      F   87.0   NaN   97.0   86.0
# 6         DY   Kapoor      M   81.0    80   96.0   89.0
# 7         JK   Khanna      F   40.0    88   95.0   87.0
# 8         RT  Pardesi      M   10.0    96   94.0   88.0
# 9         UV  Pardesi      M    9.0   NaN   93.0   96.0
# 10        MN    Desai      F  200.0    87    NaN    NaN
# 11        BC    Patel      F  300.0   NaN   88.0  300.0
# 12        DS    Patel      F  300.0   NaN   88.0  100.0
# 13        XY    Patel      F  300.0   NaN   88.0  200.0
# 14        BC    Patel      F  300.0   NaN   88.0  300.0

# %%
new_df = df.dropna(axis=0)
new_df
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT    DA
# 0        LA      Roy      M  85.0    88   90.0  92.0
# 1        SA    Dixit      F  90.0    90   94.0  95.0
# 3        DA   Kapoor      M  95.0    86  500.0  82.0
# 6        DY   Kapoor      M  81.0    80   96.0  89.0
# 7        JK   Khanna      F  40.0    88   95.0  87.0
# 8        RT  Pardesi      M  10.0    96   94.0  88.0

# %%
new_df = df.dropna(axis=1, how='all')   # drop columns with all missing values
new_df = df.dropna(axis=1, how='any')   # drop columns with any missing values
new_df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT     DA
# 0         LA      Roy      M   85.0    88   90.0   92.0
# 1         SA    Dixit      F   90.0    90   94.0   95.0
# 2         AB   Danial      M    NaN    na  100.0   80.0
# 3         DA   Kapoor      M   95.0    86  500.0   82.0
# 4         SA      Jha      F    NaN    84   98.0   84.0
# 5         WS   Thakur      F   87.0   NaN   97.0   86.0
# 6         DY   Kapoor      M   81.0    80   96.0   89.0
# 7         JK   Khanna      F   40.0    88   95.0   87.0
# 8         RT  Pardesi      M   10.0    96   94.0   88.0
# 9         UV  Pardesi      M    9.0   NaN   93.0   96.0
# 10        MN    Desai      F  200.0    87    NaN    NaN
# 11        BC    Patel      F  300.0   NaN   88.0  300.0
# 12        DS    Patel      F  300.0   NaN   88.0  100.0
# 13        XY    Patel      F  300.0   NaN   88.0  200.0
# 14        BC    Patel      F  300.0   NaN   88.0  300.0

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT     DA
# 0         LA      Roy      M   85.0    88   90.0   92.0
# 1         SA    Dixit      F   90.0    90   94.0   95.0
# 2         AB   Danial      M    NaN    na  100.0   80.0
# 3         DA   Kapoor      M   95.0    86  500.0   82.0
# 4         SA      Jha      F    NaN    84   98.0   84.0
# 5         WS   Thakur      F   87.0   NaN   97.0   86.0
# 6         DY   Kapoor      M   81.0    80   96.0   89.0
# 7         JK   Khanna      F   40.0    88   95.0   87.0
# 8         RT  Pardesi      M   10.0    96   94.0   88.0
# 9         UV  Pardesi      M    9.0   NaN   93.0   96.0
# 10        MN    Desai      F  200.0    87    NaN    NaN
# 11        BC    Patel      F  300.0   NaN   88.0  300.0
# 12        DS    Patel      F  300.0   NaN   88.0  100.0
# 13        XY    Patel      F  300.0   NaN   88.0  200.0
# 14        BC    Patel      F  300.0   NaN   88.0  300.0

# %%
df['SPOS'].fillna(df['SPOS'].mean(), inplace=True)  # fill missing values with mean
df
# Out:
#    Firstname Lastname Gender        SPOS  DSBDA     WT     DA
# 0         LA      Roy      M   85.000000   88.0   90.0   92.0
# 1         SA    Dixit      F   90.000000   90.0   94.0   95.0
# 2         AB   Danial      M  145.923077    NaN  100.0   80.0
# 3         DA   Kapoor      M   95.000000   86.0  500.0   82.0
# 4         SA      Jha      F  145.923077   84.0   98.0   84.0
# 5         WS   Thakur      F   87.000000    NaN   97.0   86.0
# 6         DY   Kapoor      M   81.000000   80.0   96.0   89.0
# 7         JK   Khanna      F   40.000000   88.0   95.0   87.0
# 8         RT  Pardesi      M   10.000000   96.0   94.0   88.0
# 9         UV  Pardesi      M    9.000000    NaN   93.0   96.0
# 10        MN    Desai      F  200.000000   87.0    NaN    NaN
# 11        BC    Patel      F  300.000000    NaN   88.0  300.0
# 12        DS    Patel      F  300.000000    NaN   88.0  100.0
# 13        XY    Patel      F  300.000000    NaN   88.0  200.0
# ...

# %%
df['DSBDA'].fillna(df['DSBDA'].mean(), inplace=True) # fill missing values with mean
df
# Out:
# /var/folders/vc/x0js5pdx54jgz2lkj9zlbygw0000gn/T/ipykernel_25119/158389862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DSBDA'].fillna(df['DSBDA'].mean(), inplace=True) # fill missing values with mean
#    Firstname Lastname Gender        SPOS   DSBDA     WT     DA
# 0         LA      Roy      M   85.000000  88.000   90.0   92.0
# 1         SA    Dixit      F   90.000000  90.000   94.0   95.0
# 2         AB   Danial      M  145.923077  87.375  100.0   80.0
# ...

# %%
df["DA"].fillna(df['DA'].mean(), inplace=True) # fill missing values with mean
df
# Out:
# /var/folders/vc/x0js5pdx54jgz2lkj9zlbygw0000gn/T/ipykernel_25119/882835788.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["DA"].fillna(df['DA'].mean(), inplace=True) # fill missing values with mean
#    Firstname Lastname Gender        SPOS   DSBDA     WT          DA
# 0         LA      Roy      M   85.000000  88.000   90.0   92.000000
# 1         SA    Dixit      F   90.000000  90.000   94.0   95.000000
# 2         AB   Danial      M  145.923077  87.375  100.0   80.000000
# ...

# %%
df['WT'].fillna(df['WT'].mean(), inplace=True) # fill missing values with mean
df
# Out:
# /var/folders/vc/x0js5pdx54jgz2lkj9zlbygw0000gn/T/ipykernel_25119/3026988386.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WT'].fillna(df['WT'].mean(), inplace=True) # fill missing values with mean
#    Firstname Lastname Gender        SPOS   DSBDA          WT          DA
# 0         LA      Roy      M   85.000000  88.000   90.000000   92.000000
# 1         SA    Dixit      F   90.000000  90.000   94.000000   95.000000
# 2         AB   Danial      M  145.923077  87.375  100.000000   80.000000
# ...

# %%
df.shape
# Out:
# (15, 7)

# %%
df.dtypes
# Out:
# Firstname    string[python]
# Lastname             object
# Gender                int64
# SPOS                float64
# DSBDA               float64
# WT                  float64
# DA                  float64
# dtype: object

# %%
df['Firstname'] = df['Firstname'].astype('string')
df.dtypes
# Out:
# Firstname    string[python]
# Lastname             object
# Gender               object
# SPOS                float64
# DSBDA               float64
# WT                  float64
# DA                  float64
# dtype: object

# %%
df['Gender'] = df['Gender'].map({'M': 1, 'F': 0}) # convert categorical to numerical
df
# Out:
#    Firstname Lastname  Gender        SPOS   DSBDA          WT          DA
# 0         LA      Roy       1   85.000000  88.000   90.000000   92.000000
# 1         SA    Dixit       0   90.000000  90.000   94.000000   95.000000
# 2         AB   Danial       1  145.923077  87.375  100.000000   80.000000
# 3         DA   Kapoor       1   95.000000  86.000  500.000000   82.000000
# 4         SA      Jha       0  145.923077  84.000   98.000000   84.000000
# 5         WS   Thakur       0   87.000000  87.375   97.000000   86.000000
# 6         DY   Kapoor       1   81.000000  80.000   96.000000   89.000000
# 7         JK   Khanna       0   40.000000  88.000   95.000000   87.000000
# 8         RT  Pardesi       1   10.000000  96.000   94.000000   88.000000
# 9         UV  Pardesi       1    9.000000  87.375   93.000000   96.000000
# 10        MN    Desai       0  200.000000  87.000  122.071429  127.071429
# 11        BC    Patel       0  300.000000  87.375   88.000000  300.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.title('Boxplot of SPOS')
plt.xlabel('SPOS')
plt.ylabel('Values')
plt.grid() 
plt.boxplot(x=df['SPOS']) 
plt.show()

# %%
plt.hist(df['DA'], color='green', edgecolor='black', alpha=0.7)
plt.grid()
plt.title("Histogram of DA")
plt.xlabel("DA")
plt.ylabel("Frequency")
plt.show()
